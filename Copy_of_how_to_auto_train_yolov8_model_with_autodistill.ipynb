# %% [markdown]
# <a href="https://colab.research.google.com/github/Viddesh1/Bottle_Cap_Detection_YOLOv8/blob/main/Copy_of_how_to_auto_train_yolov8_model_with_autodistill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://ik.imagekit.io/roboflow/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Auto Train YOLOv8 Model with Autodistill
#
# Autodistill uses big, slower foundation models to train small, faster supervised models. Using `autodistill`, you can go from unlabeled images to inference on a custom model running at the edge with no human intervention in between.
#
# ![Autodistill Steps](https://media.roboflow.com/open-source/autodistill/steps.jpg)
#
# As foundation models get better and better they will increasingly be able to augment or replace humans in the labeling process. We need tools for steering, utilizing, and comparing these models. Additionally, these foundation models are big, expensive, and often gated behind private APIs. For many production use-cases, we need models that can run cheaply and in realtime at the edge.
#
# ![Autodistill Connections](https://media.roboflow.com/open-source/autodistill/connections.jpg)
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Image dataset preperation
# - Autolabel dataset
# - Train target model
# - Evaluate target model
# - Run video inference
# - Upload dataset and model to Roboflow (comming soon)
#
# ## 🔥 Let's begin!

# %% [markdown]
# ## ⚡ Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !rm -rf Drive

# %%
# !nvidia-smi
# Out:
# Sat Oct  7 08:10:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 🧪 Install autodistill
#
# **NOTE:** Autodistill is an ecosystem for using big, slower foundation models to train small, faster supervised models. Each Base, as well as the Target model, has its own separate repository and pip package.

# %%
# !pip install -q \
autodistill \
autodistill-grounded-sam \
autodistill-yolov8 \
supervision==0.9.0

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## 🖼️ Image dataset preperation
#
# **NOTE:** To use Autodistill all you need to have is a set of images that you want to automatically annotate, and use for target model training.

# %%
# !mkdir {HOME}/images

# %% [markdown]
# **NOTE:** If you want to build YOLOv8 on your data make sure to upload it into `images` directory that we just created. ☝️

# %% [markdown]
# ### Download raw videos (optional)
#
# **NOTE:** In this tutorial, we will start with a directory containing video files and I will show you how to turn it into a ready-to-use collection of images. If you are working with your images, you can skip this part.

# %%
# !mkdir {HOME}/videos
# %cd {HOME}/videos

# download zip file containing videos
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt" -O milk.zip && rm -rf /tmp/cookies.txt

# unzip videos
# !unzip milk.zip
# Out:
# /content/videos
# --2023-10-07 08:10:50--  https://docs.google.com/uc?export=download&confirm=t&id=1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt
# Resolving docs.google.com (docs.google.com)... 142.251.2.138, 142.251.2.101, 142.251.2.100, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gvmsp04bll8sg94v8c9u5778aifh2l09/1696666200000/04309230031174164349/*/1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt?e=download&uuid=c63da460-b370-4a6f-80a2-ef60530891d9 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-07 08:10:50--  https://doc-08-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gvmsp04bll8sg94v8c9u5778aifh2l09/1696666200000/04309230031174164349/*/1wnW7v6UTJZTAcOQj0416ZbQF8b7yO6Pt?e=download&uuid=c63da460-b370-4a6f-80a2-ef60530891d9
# Resolving doc-08-ag-docs.googleusercontent.com (doc-08-ag-docs.googleusercontent.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to doc-08-ag-docs.googleusercontent.com (doc-08-ag-docs.googleusercontent.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1192719976 (1.1G) [application/zip]
# Saving to: ‘milk.zip’
#
# milk.zip            100%[===================>]   1.11G  92.0MB/s    in 12s
#
# 2023-10-07 08:11:03 (91.4 MB/s) - ‘milk.zip’ saved [1192719976/1192719976]
#
# Archive:  milk.zip
#   inflating: milk-video-1.mov
#   inflating: milk-video-2.mov
#   inflating: milk-video-3.mov
#   inflating: milk-video-4.mov
#   inflating: milk-video-5.mov
#   inflating: milk-video-6.mov
#   inflating: milk-video-7.mov
#   inflating: milk-video-8.mov

# %% [markdown]
# ### Convert videos into images (optional)
#
# **NOTE:** Now, let's convert videos into images. By default, the code below saves every `10th` frame from each video. You can change this by manipulating the value of the `FRAME_STRIDE` parameter.

# %%
VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 3

# %% [markdown]
# **NOTE:** Notice that we put two of our videos aside so that we can use them at the end of the notebook to evaluate our model.

# %%
import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

print(video_paths)

for video_path in tqdm(video_paths):
    video_name = video_path.stem
    image_name_pattern = video_name + "-{:05d}.png"
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            sink.save_image(image=image)
# Out:
# [PosixPath('/content/videos/milk-video-1.mov')]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Display image sample
#
# **NOTE:** Before we start building a model with autodistill, let's make sure we have everything we need.

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 63

# %% [markdown]
# **NOTE:** We can also plot sample of our image dataset.

# %%
IMAGE_DIR_PATH = f"{HOME}/images"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 16)

# %%
import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🏷️ Autolabel dataset

# %% [markdown]
# ### Define ontology
#
# **Ontology** - an Ontology defines how your Base Model is prompted, what your Dataset will describe, and what your Target Model will predict. A simple Ontology is the CaptionOntology which prompts a Base Model with text captions and maps them to class names. Other Ontologies may, for instance, use a CLIP vector or example images instead of a text caption.

# %%
from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    "milk bottle": "Bottle",
    "blue cap": "cap"
})

# %% [markdown]
# ### Initiate base model and autolabel
#
# **Base Model** - A Base Model is a large foundation model that knows a lot about a lot. Base models are often multimodal and can perform many tasks. They're large, slow, and expensive. Examples of Base Models are GroundedSAM and GPT-4's upcoming multimodal variant. We use a Base Model (along with unlabeled input data and an Ontology) to create a Dataset.

# %%
DATASET_DIR_PATH = f"{HOME}/dataset"

# %% [markdown]
# **NOTE:** Base Models are slow... Make yourself a coffee, autolabeing may take a while. ☕

# %%
from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# trying to load grounding dino directly
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# Labeling /content/images/milk-video-1-00054.png:   0%|          | 0/63 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:905: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:905: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# Labeling /content/images/milk-video-1-00006.png: 100%|██████████| 63/63 [03:55<00:00,  3.73s/it]
# Labeled dataset created - ready for distillation.

# %% [markdown]
# ### Display dataset sample
#
# **Dataset** - a Dataset is a set of auto-labeled data that can be used to train a Target Model. It is the output generated by a Base Model.

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/dataset/train/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/dataset/train/images"
DATA_YAML_PATH = f"{HOME}/dataset/data.yaml"

# %%
import supervision as sv

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=IMAGES_DIRECTORY_PATH,
    annotations_directory_path=ANNOTATIONS_DIRECTORY_PATH,
    data_yaml_path=DATA_YAML_PATH)

len(dataset)
# Out:
# 50

# %%
import supervision as sv

image_names = list(dataset.images.keys())[:SAMPLE_SIZE]

mask_annotator = sv.MaskAnnotator()
box_annotator = sv.BoxAnnotator()

images = []
for image_name in image_names:
    image = dataset.images[image_name]
    annotations = dataset.annotations[image_name]
    labels = [
        dataset.classes[class_id]
        for class_id
        in annotations.class_id]
    annotates_image = mask_annotator.annotate(
        scene=image.copy(),
        detections=annotations)
    annotates_image = box_annotator.annotate(
        scene=annotates_image,
        detections=annotations,
        labels=labels)
    images.append(annotates_image)

sv.plot_images_grid(
    images=images,
    titles=image_names,
    grid_size=SAMPLE_GRID_SIZE,
    size=SAMPLE_PLOT_SIZE)

# %% [markdown]
# ## 🔥 Train target model - YOLOv8
#
# **Target Model** - a Target Model is a supervised model that consumes a Dataset and outputs a distilled model that is ready for deployment. Target Models are usually small, fast, and fine-tuned to perform a specific task very well (but they don't generalize well beyond the information described in their Dataset). Examples of Target Models are YOLOv8 and DETR.

# %%
# %cd {HOME}

from autodistill_yolov8 import YOLOv8

target_model = YOLOv8("yolov8l.pt")
target_model.train(DATA_YAML_PATH, epochs=10) #100
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt to yolov8l.pt...
# 100%|██████████| 83.7M/83.7M [00:01<00:00, 73.5MB/s]
# New https://pypi.org/project/ultralytics/8.0.194 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8l.pt, data=/content/dataset/data.yaml, epochs=10, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 22.4MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.Conv                  [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.C2f                   [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.C2f                   [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.C2f                   [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.C2f                   [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.C2f                   [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.C2f                   [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  22        [15, 18, 21]  1   5584342  ultralytics.nn.modules.Detect                [2, [256, 512, 512]]
# Model summary: 365 layers, 43631382 parameters, 43631366 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 100MB/s]
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias
# train: Scanning /content/dataset/train/labels... 50 images, 0 backgrounds, 0 corrupt: 100%|██████████| 50/50 [00:00<00:00, 384.07it/s]
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/valid/labels... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<00:00, 262.79it/s]
# val: New cache created: /content/dataset/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      13.2G      2.357      3.453      2.147         24        640: 100%|██████████| 4/4 [00:10<00:00,  2.52s/it]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.78s/it]
#                    all         13         59    0.00787      0.519    0.00772    0.00299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      13.9G      2.255      3.342      2.074         16        640: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
#                    all         13         59    0.00674      0.462      0.007    0.00246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10        14G      2.304      3.383      2.072         23        640: 100%|██████████| 4/4 [00:05<00:00,  1.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.38it/s]
#                    all         13         59    0.00657      0.448    0.00666    0.00197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      14.1G      1.669      3.059      1.501         26        640: 100%|██████████| 4/4 [00:06<00:00,  1.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
#                    all         13         59     0.0413     0.0694     0.0169    0.00784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      14.1G      1.292      2.572      1.281         36        640: 100%|██████████| 4/4 [00:02<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
#                    all         13         59     0.0123     0.0972     0.0229     0.0118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      14.1G     0.9778      2.106      1.195         26        640: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.46it/s]
#                    all         13         59      0.589      0.384      0.476      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      14.2G     0.8157      1.473      1.087         41        640: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
#                    all         13         59      0.579      0.587      0.569      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      14.1G     0.7001      1.233       1.03         23        640: 100%|██████████| 4/4 [00:02<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
#                    all         13         59      0.668      0.706      0.745      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      14.1G     0.6463      1.054     0.9831         11        640: 100%|██████████| 4/4 [00:02<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
#                    all         13         59      0.769      0.649      0.792      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      14.1G     0.6398      1.071      1.003         20        640: 100%|██████████| 4/4 [00:02<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
#                    all         13         59      0.834      0.548      0.839      0.651
#
# 10 epochs completed in 0.038 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 87.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 87.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.46it/s]
#                    all         13         59      0.834      0.548      0.839      0.651
#                 Bottle         13         36      0.668      0.778      0.787      0.597
#                    cap         13         23          1      0.318       0.89      0.705
# Speed: 0.2ms preprocess, 11.4ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train

# %% [markdown]
# ## ⚖️ Evaluate target model
#
# **NOTE:** As with the regular YOLOv8 training, we can now take a look at artifacts stored in `runs` directory.

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}

from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## 🎬 Run Inference on a video

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# TEST_VIDEO_PATHS = f"/content/videos/milk-video-1.mov"
INPUT_VIDEO_PATH = f"/content/videos/milk-video-1.mov"
OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# TEST_VIDEO_PATHS = f"/content/videos/milk-video-1.mov"
# INPUT_VIDEO_PATH = TEST_VIDEO_PATHS[0]
# OUTPUT_VIDEO_PATH = f"{HOME}/output.mp4"
# TRAINED_MODEL_PATH = f"{HOME}/runs/detect/train/weights/best.pt"

# %%
# !yolo predict model={TRAINED_MODEL_PATH} source={INPUT_VIDEO_PATH}
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#
# video 1/1 (1/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 128.4ms
# video 1/1 (2/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 40.7ms
# video 1/1 (3/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 40.8ms
# video 1/1 (4/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 39.9ms
# video 1/1 (5/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 39.9ms
# video 1/1 (6/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 36.9ms
# video 1/1 (7/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 31.9ms
# video 1/1 (8/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 31.8ms
# video 1/1 (9/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 1 cap, 31.9ms
# video 1/1 (10/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 31.9ms
# video 1/1 (11/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 31.9ms
# video 1/1 (12/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 27.9ms
# video 1/1 (13/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 27.7ms
# video 1/1 (14/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 27.2ms
# video 1/1 (15/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 27.4ms
# video 1/1 (16/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (17/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 28.6ms
# video 1/1 (18/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 26.5ms
# video 1/1 (19/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 30.1ms
# video 1/1 (20/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 26.5ms
# video 1/1 (21/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 29.0ms
# video 1/1 (22/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 26.5ms
# video 1/1 (23/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 26.5ms
# video 1/1 (24/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.5ms
# video 1/1 (25/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 36.9ms
# video 1/1 (26/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 33.5ms
# video 1/1 (27/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (28/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 1 cap, 26.5ms
# video 1/1 (29/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 26.5ms
# video 1/1 (30/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 33.5ms
# video 1/1 (31/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 28.2ms
# video 1/1 (32/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 26.5ms
# video 1/1 (33/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 31.0ms
# video 1/1 (34/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 30.8ms
# video 1/1 (35/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 30.5ms
# video 1/1 (36/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 36.9ms
# video 1/1 (37/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 47.0ms
# video 1/1 (38/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 30.9ms
# video 1/1 (39/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 31.4ms
# video 1/1 (40/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 31.4ms
# video 1/1 (41/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 31.9ms
# video 1/1 (42/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 31.9ms
# video 1/1 (43/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 32.4ms
# video 1/1 (44/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 33.3ms
# video 1/1 (45/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 32.9ms
# video 1/1 (46/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 39.1ms
# video 1/1 (47/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 39.0ms
# video 1/1 (48/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 37.0ms
# video 1/1 (49/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 39.5ms
# video 1/1 (50/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 35.4ms
# video 1/1 (51/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 34.1ms
# video 1/1 (52/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 36.2ms
# video 1/1 (53/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 34.7ms
# video 1/1 (54/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 34.7ms
# video 1/1 (55/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 30.9ms
# video 1/1 (56/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 31.2ms
# video 1/1 (57/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 31.0ms
# video 1/1 (58/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 30.9ms
# video 1/1 (59/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 30.7ms
# video 1/1 (60/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 29.1ms
# video 1/1 (61/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 29.1ms
# video 1/1 (62/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 29.1ms
# video 1/1 (63/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 1 cap, 29.1ms
# video 1/1 (64/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 29.3ms
# video 1/1 (65/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 27.4ms
# video 1/1 (66/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 32.9ms
# video 1/1 (67/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.7ms
# video 1/1 (68/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.5ms
# video 1/1 (69/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 28.0ms
# video 1/1 (70/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 26.5ms
# video 1/1 (71/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 28.4ms
# video 1/1 (72/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 28.2ms
# video 1/1 (73/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 34.6ms
# video 1/1 (74/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (75/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 26.6ms
# video 1/1 (76/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.5ms
# video 1/1 (77/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.4ms
# video 1/1 (78/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (79/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.5ms
# video 1/1 (80/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (81/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (82/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 26.5ms
# video 1/1 (83/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.5ms
# video 1/1 (84/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 26.5ms
# video 1/1 (85/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 26.5ms
# video 1/1 (86/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 26.4ms
# video 1/1 (87/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 26.5ms
# video 1/1 (88/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 25.5ms
# video 1/1 (89/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 25.3ms
# video 1/1 (90/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 25.2ms
# video 1/1 (91/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 1 cap, 24.3ms
# video 1/1 (92/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 24.4ms
# video 1/1 (93/188) /content/videos/milk-video-1.mov: 384x640 1 Bottle, 22.9ms
# video 1/1 (94/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 22.5ms
# video 1/1 (95/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 22.3ms
# video 1/1 (96/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 22.4ms
# video 1/1 (97/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 22.3ms
# video 1/1 (98/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 22.4ms
# video 1/1 (99/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 22.4ms
# video 1/1 (100/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 22.4ms
# video 1/1 (101/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 22.4ms
# video 1/1 (102/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 1 cap, 22.4ms
# video 1/1 (103/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 1 cap, 27.4ms
# video 1/1 (104/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 22.3ms
# video 1/1 (105/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 1 cap, 22.4ms
# video 1/1 (106/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 22.4ms
# video 1/1 (107/188) /content/videos/milk-video-1.mov: 384x640 2 Bottles, 22.4ms
# video 1/1 (108/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 22.3ms
# video 1/1 (109/188) /content/videos/milk-video-1.mov: 384x640 3 Bottles, 22.0ms
# video 1/1 (110/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 26.8ms
# video 1/1 (111/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.6ms
# video 1/1 (112/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 21.6ms
# video 1/1 (113/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 21.6ms
# video 1/1 (114/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 21.9ms
# video 1/1 (115/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.9ms
# video 1/1 (116/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 22.0ms
# video 1/1 (117/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 22.0ms
# video 1/1 (118/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 21.6ms
# video 1/1 (119/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.9ms
# video 1/1 (120/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 22.0ms
# video 1/1 (121/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 22.0ms
# video 1/1 (122/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 22.0ms
# video 1/1 (123/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 22.0ms
# video 1/1 (124/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 21.9ms
# video 1/1 (125/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 21.6ms
# video 1/1 (126/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 1 cap, 21.6ms
# video 1/1 (127/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.8ms
# video 1/1 (128/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.6ms
# video 1/1 (129/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 22.0ms
# video 1/1 (130/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.9ms
# video 1/1 (131/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.6ms
# video 1/1 (132/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 21.6ms
# video 1/1 (133/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 1 cap, 21.6ms
# video 1/1 (134/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 21.6ms
# video 1/1 (135/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 2 caps, 21.5ms
# video 1/1 (136/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 21.5ms
# video 1/1 (137/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 21.5ms
# video 1/1 (138/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 2 caps, 21.5ms
# video 1/1 (139/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 2 caps, 21.5ms
# video 1/1 (140/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 3 caps, 21.5ms
# video 1/1 (141/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 3 caps, 21.4ms
# video 1/1 (142/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 3 caps, 21.2ms
# video 1/1 (143/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 3 caps, 21.6ms
# video 1/1 (144/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 4 caps, 21.4ms
# video 1/1 (145/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 4 caps, 21.7ms
# video 1/1 (146/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 5 caps, 21.1ms
# video 1/1 (147/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 5 caps, 21.1ms
# video 1/1 (148/188) /content/videos/milk-video-1.mov: 384x640 13 Bottles, 4 caps, 21.5ms
# video 1/1 (149/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 4 caps, 21.4ms
# video 1/1 (150/188) /content/videos/milk-video-1.mov: 384x640 11 Bottles, 4 caps, 21.2ms
# video 1/1 (151/188) /content/videos/milk-video-1.mov: 384x640 12 Bottles, 4 caps, 21.2ms
# video 1/1 (152/188) /content/videos/milk-video-1.mov: 384x640 10 Bottles, 4 caps, 21.4ms
# video 1/1 (153/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 4 caps, 21.5ms
# video 1/1 (154/188) /content/videos/milk-video-1.mov: 384x640 11 Bottles, 4 caps, 21.2ms
# video 1/1 (155/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 4 caps, 21.2ms
# video 1/1 (156/188) /content/videos/milk-video-1.mov: 384x640 10 Bottles, 2 caps, 21.5ms
# video 1/1 (157/188) /content/videos/milk-video-1.mov: 384x640 10 Bottles, 2 caps, 21.4ms
# video 1/1 (158/188) /content/videos/milk-video-1.mov: 384x640 12 Bottles, 3 caps, 21.2ms
# video 1/1 (159/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 3 caps, 21.2ms
# video 1/1 (160/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 3 caps, 21.2ms
# video 1/1 (161/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 5 caps, 21.2ms
# video 1/1 (162/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 5 caps, 21.2ms
# video 1/1 (163/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 4 caps, 23.3ms
# video 1/1 (164/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 4 caps, 22.9ms
# video 1/1 (165/188) /content/videos/milk-video-1.mov: 384x640 10 Bottles, 4 caps, 22.9ms
# video 1/1 (166/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 5 caps, 23.8ms
# video 1/1 (167/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 5 caps, 23.1ms
# video 1/1 (168/188) /content/videos/milk-video-1.mov: 384x640 11 Bottles, 5 caps, 23.3ms
# video 1/1 (169/188) /content/videos/milk-video-1.mov: 384x640 9 Bottles, 5 caps, 24.1ms
# video 1/1 (170/188) /content/videos/milk-video-1.mov: 384x640 8 Bottles, 4 caps, 23.3ms
# video 1/1 (171/188) /content/videos/milk-video-1.mov: 384x640 10 Bottles, 4 caps, 23.5ms
# video 1/1 (172/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 4 caps, 24.2ms
# video 1/1 (173/188) /content/videos/milk-video-1.mov: 384x640 10 Bottles, 4 caps, 23.6ms
# video 1/1 (174/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 4 caps, 24.5ms
# video 1/1 (175/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 2 caps, 24.7ms
# video 1/1 (176/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 3 caps, 24.1ms
# video 1/1 (177/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 3 caps, 25.2ms
# video 1/1 (178/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 2 caps, 25.1ms
# video 1/1 (179/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 2 caps, 24.4ms
# video 1/1 (180/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 3 caps, 24.3ms
# video 1/1 (181/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 4 caps, 24.4ms
# video 1/1 (182/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 4 caps, 24.4ms
# video 1/1 (183/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 4 caps, 25.3ms
# video 1/1 (184/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 4 caps, 25.2ms
# video 1/1 (185/188) /content/videos/milk-video-1.mov: 384x640 7 Bottles, 2 caps, 24.6ms
# video 1/1 (186/188) /content/videos/milk-video-1.mov: 384x640 6 Bottles, 2 caps, 24.6ms
# video 1/1 (187/188) /content/videos/milk-video-1.mov: 384x640 4 Bottles, 2 caps, 24.6ms
# video 1/1 (188/188) /content/videos/milk-video-1.mov: 384x640 5 Bottles, 1 cap, 24.6ms
# Speed: 0.6ms preprocess, 26.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# ## Export Model to Custom Python Script and Project

# %%
# yolo export model=yolov8n.pt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mkdir -p /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/runs /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/dataset /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/images /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/videos /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/yolov8l.pt /content/gdrive/MyDrive/YOLOv8_bottle/
# !cp -r /content/yolov8n.pt /content/gdrive/MyDrive/YOLOv8_bottle/
